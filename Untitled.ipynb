# %% [markdown]
# #  Ridge, Lasso, Ordinary Least Squares을 이용한 데이터 선형 모델의 결과
#
#
# ### 보스턴 주택 가격 데이터셋의 산점도

# %%
import numpy as np
import numpy as np
from sklearn.model_selection import train_test_split
 
from sklearn.datasets import load_boston
boston = load_boston()

# %%
import matplotlib.pyplot as plt
# x: average number of rooms per dwelling(방 개수), y: 주택 가격
plt.scatter(boston.data[:, 5], boston.target, color='r', s=10)

# %% [markdown]
# ### 보스턴 주택 가격 데이터셋에 선형회귀를 적용 한 결과

# %%
from sklearn.linear_model import LinearRegression
X, y = mglearn.datasets.load_extended_boston()

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
lr = LinearRegression().fit(X_train, y_train)

print("훈련 세트 점수: {:.2f}".format(lr.score(X_train, y_train)))
print("테스트 세트 점수: {:.2f}".format(lr.score(X_test, y_test)))
# Out:
# 훈련 세트 점수: 0.95
# 테스트 세트 점수: 0.61

# %% [markdown]
# 훈련 데이터와 테스트 데이터 사이의 성능차이로 보아 모델이 과대적합 되었다는 것을 알 수 있음.

# %% [markdown]
# ### 보스턴 주택 가격 데이터셋에 릿지 회귀를 적용 한 결과

# %%
from sklearn.linear_model import Ridge

ridge = Ridge().fit(X_train, y_train)
print("훈련 세트 점수: {:.2f}".format(ridge.score(X_train, y_train)))
print("테스트 세트 점수: {:.2f}".format(ridge.score(X_test, y_test)))
# Out:
# 훈련 세트 점수: 0.89
# 테스트 세트 점수: 0.75

# %% [markdown]
# 테스트 세트에 대한 점수가 더 높은것으로 과대적합이 적어진 것을 확인 할 수 있음.

# %% [markdown]
# 알파값을 재조정하여 테스트를 한 결과

# %%
ridge01 = Ridge(alpha=0.1).fit(X_train, y_train)
print("훈련 세트 점수: {:.2f}".format(ridge01.score(X_train, y_train)))
print("테스트 세트 점수: {:.2f}".format(ridge01.score(X_test, y_test)))
# Out:
# 훈련 세트 점수: 0.93
# 테스트 세트 점수: 0.77

# %% [markdown]
# 보스턴 주택 가격에 대한 학습 곡선

# %%
mglearn.plots.plot_ridge_n_samples()

# %% [markdown]
#     모든 데이터셋에 대하여 릿지와 선형 회귀 모두 훈련 세트의 점수가 테스트 세트의 점수보다 높다.
#     두 모델의 성능은 데이터가 많아질수록 좋아지고 마지막에는 선형회귀가 릿지회귀를 따라잡는 것으로 보아
#     데이터가 많아질수록 규제 항은 덜 중요하고 과대적합이 덜 발생한다는 것을 알 수 있음

# %% [markdown]
# ### 보스턴 주택 가격 데이터셋에 라쏘를 적용 한 결과

# %%
from sklearn.linear_model import Lasso

lasso = Lasso().fit(X_train, y_train)
print("훈련 세트 점수: {:.2f}".format(lasso.score(X_train, y_train)))
print("테스트 세트 점수: {:.2f}".format(lasso.score(X_test, y_test)))
print("사용한 특성의 수: {}".format(np.sum(lasso.coef_ != 0)))
# Out:
# 훈련 세트 점수: 0.29
# 테스트 세트 점수: 0.21
# 사용한 특성의 수: 4

# %% [markdown]
# 104개의 특성 중 4개만 사용하여 과소적합이 발생하여 alpha를 수정하여 다시 적용한 결과

# %%
# "max_iter" 기본값을 증가시키지 않으면 max_iter 값을 늘리라는 경고가 발생
lasso001 = Lasso(alpha=0.01, max_iter=100000).fit(X_train, y_train)
print("훈련 세트 점수: {:.2f}".format(lasso001.score(X_train, y_train)))
print("테스트 세트 점수: {:.2f}".format(lasso001.score(X_test, y_test)))
print("사용한 특성의 수: {}".format(np.sum(lasso001.coef_ != 0)))
# Out:
# 훈련 세트 점수: 0.90
# 테스트 세트 점수: 0.77
# 사용한 특성의 수: 33

# %% [markdown]
# 그러나 alpha 값을 너무 낮우면 과대적합이 되므로 LinearRegression과 비슷한 결과가 나옴.

# %%
# "max_iter" 기본값을 증가시키지 않으면 max_iter 값을 늘리라는 경고가 발생
lasso001 = Lasso(alpha=0.0001, max_iter=100000).fit(X_train, y_train)
print("훈련 세트 점수: {:.2f}".format(lasso001.score(X_train, y_train)))
print("테스트 세트 점수: {:.2f}".format(lasso001.score(X_test, y_test)))
print("사용한 특성의 수: {}".format(np.sum(lasso001.coef_ != 0)))
# Out:
# 훈련 세트 점수: 0.95
# 테스트 세트 점수: 0.64
# 사용한 특성의 수: 94
